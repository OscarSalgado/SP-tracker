# %% [markdown]
# # Classifier-Guided Blind Deconvolution
#
# **ArXiv**: [2404.15341](https://arxiv.org/abs/2404.15341)

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '.')

from src import ClassifierGuidedBD

print("✓ Librerías cargadas")

# %%
t = np.arange(0, 2, 0.0001)
signal = np.sin(2 * np.pi * 100 * t) + 0.5 * np.random.randn(len(t))

cbd = ClassifierGuidedBD()
result = cbd.diagnose(signal)

print(f"Diagnóstico: {result['fault_name']}")
print(f"OK")
