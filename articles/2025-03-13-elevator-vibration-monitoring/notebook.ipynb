# %% [markdown]
# # Monitoreo de Vibraciones en Ascensores: STAN + DSAN
# Notebook de reproduccion de resultados.

# %%
import torch
import numpy as np
print(f'PyTorch: {torch.__version__}')

# %% [markdown]
# ## Generacion de datos

# %%
np.random.seed(42)
signals = np.random.randn(100, 4096)
print(f'Generated {len(signals)} signals')

# %% [markdown]
# ## Modelo

# %%
from src.models import ShuffleNetV2STAN
model = ShuffleNetV2STAN(num_classes=4)
print(f'Model created: {sum(p.numel() for p in model.parameters())} parameters')

# %%
print('SUCCESS: Notebook executed')
